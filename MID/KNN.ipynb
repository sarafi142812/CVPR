# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install opencv-python-headless

import os
import random
import cv2
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.11/dist-packages (from opencv-python-headless) (2.0.2)

# %%
import os
image_dir = '/content/drive/MyDrive/animal'
Categories = [c for c in os.listdir(image_dir)]
print(Categories)
# Out:
# ['cats', 'dogs', 'panda']

# %%
train_data = []
IMG_SIZE = 64

for c in Categories:
    path = os.path.join(image_dir, c)
    class_num = Categories.index(c)
    for img in os.listdir(path):
        try:
            img_arr = cv2.imread(os.path.join(path, img))
            img_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
            train_data.append([img_arr, class_num])
        except Exception as e:
            pass

print(f"\nTotal images: {len(train_data)}")
# Out:
# Total images: 900

# %%
random.shuffle(train_data)
plt.figure(figsize=(18,12))
for i in range(20):
    plt.subplot(4,5,i+1)
    image = train_data[i][0]
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    plt.imshow(image_gray, cmap="gray")
    plt.xlabel(Categories[train_data[i][1]])
    plt.xticks([]); plt.yticks([])
plt.show()

# %%
def l1_dist(image1, image2):
    return np.sum(np.abs(image1 - image2)) #abs = absulate value

def l2_dist(image1, image2):
    return np.sqrt(np.sum((image1 - image2) ** 2))

# %%
def l1_dist(image1, image2):
    return np.sum(np.abs(image1 - image2)) #abs = absulate value

def l2_dist(image1, image2):
    return np.sqrt(np.sum((image1 - image2) ** 2))

# %%
f0 = train_data[0:60]
f1 = train_data[60:120]
f2 = train_data[120:180]
f3 = train_data[180:240]
f4 = train_data[240:300]

# %%
top_filter = 20
from tqdm import tqdm


def distance_calc(train_fold, valid_fold):
    l1_result = []
    l2_result = []
    for valid in tqdm(valid_fold, desc="Calculating distances"):
        temp_dist_list = []
        for train in train_fold:
            l1_distance = l1_dist(valid[0], train[0])
            l2_distance = l2_dist(valid[0], train[0])
            temp_dist_list.append([valid[1], train[1], {"l1": l1_distance, "l2": l2_distance}])
        temp_dist_list.sort(key=lambda l: l[2]["l1"])
        l1_result.append(temp_dist_list[:top_filter])
        temp_dist_list.sort(key=lambda l: l[2]["l2"])
        l2_result.append(temp_dist_list[:top_filter])
    return [l1_result, l2_result]


dist_by_fold = []
folds = [f0, f1, f2, f3, f4]
for i in range(5):
    valid = folds[i]
    train = sum([folds[j] for j in range(5) if j != i], [])
    dist_by_fold.append(distance_calc(train, valid))
# Out:
# Calculating distances: 100%|██████████| 60/60 [00:00<00:00, 129.39it/s]
# Calculating distances: 100%|██████████| 60/60 [00:00<00:00, 130.01it/s]
# Calculating distances: 100%|██████████| 60/60 [00:00<00:00, 133.85it/s]
# Calculating distances: 100%|██████████| 60/60 [00:00<00:00, 129.27it/s]
# Calculating distances: 100%|██████████| 60/60 [00:00<00:00, 134.07it/s]

# %%
k_range = 20

def cal_accuracy(dist_result, dist_term):
    k_accuracies = []
    for k in range(1, k_range+1):
        img_accuracy = 0
        for valid_img in dist_result:
            nn = valid_img[:k]
            same_class = [n for n in nn if n[0] == n[1]]
            same_class_len = len(same_class)
            if k % 2 != 0:
                if ((k-1) / 2) < same_class_len:
                    img_accuracy += 1
            else:
                diff_class = [n for n in nn if n[0] != n[1]]
                if same_class_len > len(diff_class):
                    img_accuracy += 1
                elif same_class_len == len(diff_class):
                    same_class_dist = sum([n[2][dist_term] for n in same_class])
                    diff_class_dist = sum([n[2][dist_term] for n in diff_class])
                    if same_class_dist > diff_class_dist:
                        img_accuracy += 1
        k_accuracies.append(img_accuracy/len(dist_result))
    return k_accuracies

accuracies = []
for result in dist_by_fold:
    l1_accuracy = cal_accuracy(result[0], "l1")
    l2_accuracy = cal_accuracy(result[1], "l2")
    accuracies.append([l1_accuracy, l2_accuracy])

# %%
x_list = list(range(1, k_range+1))

plt.style.use('seaborn-v0_8-darkgrid')

fig, axes = plt.subplots(1, 2, figsize=(16, 7)) # Use subplots with a figure object

# L1 Distance Plot
ax1 = axes[0]
for fold in accuracies:
    y_list = fold[0]
    ax1.scatter(x_list, y_list, alpha=0.6, label='_nolegend_')
arr_l1 = [[fold[0][i] for fold in accuracies] for i in range(k_range)]
trend_l1 = [np.mean(a) for a in arr_l1]
ax1.plot(x_list, trend_l1, marker='o', linestyle='-', color='red', label='Mean Accuracy')
ax1.set_title('Accuracy vs. K (L1 Distance)', fontsize=14)
ax1.set_xlabel('K (Number of Neighbors)', fontsize=12)
ax1.set_ylabel('Accuracy', fontsize=12)
ax1.set_ylim(0.2, 0.5)
ax1.legend()

# L2 Distance Plot
ax2 = axes[1]
for fold in accuracies:
    y_list = fold[1]
    ax2.scatter(x_list, y_list, alpha=0.6, label='_nolegend_') # Added alpha for better visibility
arr_l2 = [[fold[1][i] for fold in accuracies] for i in range(k_range)]
trend_l2 = [np.mean(a) for a in arr_l2]
ax2.plot(x_list, trend_l2, marker='o', linestyle='-', color='blue', label='Mean Accuracy')
ax2.set_title('Accuracy vs. K (L2 Distance)', fontsize=14)
ax2.set_xlabel('K (Number of Neighbors)', fontsize=12)
ax2.set_ylabel('Accuracy', fontsize=12)
ax2.set_ylim(0.2, 0.5)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
# Shuffle and select 10 grayscale test images
random.shuffle(train_data)
test_images = []
for i in range(10):
    test_image = train_data[i][0]
    test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
    test_images.append(test_image_gray)

# Predict top 5 using L1 Distance
print("Top 5 Predictions for L1 Distance (10 test samples):\n")
for idx, test_image_gray in enumerate(test_images):
    print(f"Test Image {idx + 1}:")
    distances1 = []
    for train_image, class_num in train_data:
        train_image_gray = cv2.cvtColor(train_image, cv2.COLOR_BGR2GRAY)
        dist1 = l1_dist(test_image_gray, train_image_gray)
        distances1.append((dist1, class_num))
    distances1.sort(key=lambda x: x[0])
    for i, (dist1, class_num) in enumerate(distances1[:5]):
        predicted_class = Categories[class_num]
        print(f"  Prediction {i+1}: Class '{predicted_class}' with L1 distance {dist1/100:.2f}")
    print()

# Predict top 5 using L2 Distance
print("\nTop 5 Predictions for L2 Distance (10 test samples):\n")
for idx, test_image_gray in enumerate(test_images):
    print(f"Test Image {idx + 1}:")
    distances2 = []
    for train_image, class_num in train_data:
        train_image_gray = cv2.cvtColor(train_image, cv2.COLOR_BGR2GRAY)
        dist2 = l2_dist(test_image_gray, train_image_gray)
        distances2.append((dist2, class_num))
    distances2.sort(key=lambda x: x[0])
    for i, (dist2, class_num) in enumerate(distances2[:5]):
        predicted_class = Categories[class_num]
        print(f"  Prediction {i+1}: Class '{predicted_class}' with L2 distance {dist2:.2f}")
    print()
# Out:
# Top 5 Predictions for L1 Distance (10 test samples):
#
# Test Image 1:
#   Prediction 1: Class 'cats' with L1 distance 0.00
#   Prediction 2: Class 'cats' with L1 distance 3519.13
#   Prediction 3: Class 'dogs' with L1 distance 3562.00
#   Prediction 4: Class 'cats' with L1 distance 3574.70
#   Prediction 5: Class 'cats' with L1 distance 3600.35
#
# Test Image 2:
#   Prediction 1: Class 'dogs' with L1 distance 0.00
#   Prediction 2: Class 'panda' with L1 distance 4169.04
#   Prediction 3: Class 'panda' with L1 distance 4205.24
#   Prediction 4: Class 'panda' with L1 distance 4222.27
#   Prediction 5: Class 'cats' with L1 distance 4225.18
#
# Test Image 3:
#   Prediction 1: Class 'panda' with L1 distance 0.00
#   Prediction 2: Class 'cats' with L1 distance 3549.10
#   Prediction 3: Class 'cats' with L1 distance 3962.66
#   Prediction 4: Class 'dogs' with L1 distance 3988.37
#   Prediction 5: Class 'cats' with L1 distance 4021.28
#
# Test Image 4:
#   Prediction 1: Class 'dogs' with L1 distance 0.00
#   Prediction 2: Class 'cats' with L1 distance 3760.47
#   Prediction 3: Class 'cats' with L1 distance 3791.57
#   Prediction 4: Class 'panda' with L1 distance 3844.37
#   Prediction 5: Class 'panda' with L1 distance 3883.97
#
# Test Image 5:
#   Prediction 1: Class 'panda' with L1 distance 0.00
#   Prediction 2: Class 'cats' with L1 distance 4064.33
#   Prediction 3: Class 'panda' with L1 distance 4103.29
#   Prediction 4: Class 'panda' with L1 distance 4254.14
#   Prediction 5: Class 'cats' with L1 distance 4267.03
#
# Test Image 6:
#   Prediction 1: Class 'panda' with L1 distance 0.00
#   Prediction 2: Class 'panda' with L1 distance 3420.33
#   Prediction 3: Class 'panda' with L1 distance 3649.32
#   Prediction 4: Class 'dogs' with L1 distance 3659.52
#   Prediction 5: Class 'dogs' with L1 distance 3727.25
#
# Test Image 7:
#   Prediction 1: Class 'panda' with L1 distance 0.00
#   Prediction 2: Class 'panda' with L1 distance 3512.61
#   Prediction 3: Class 'panda' with L1 distance 3658.25
#   Prediction 4: Class 'panda' with L1 distance 3763.26
#   Prediction 5: Class 'cats' with L1 distance 3838.63
#
# Test Image 8:
#   Prediction 1: Class 'panda' with L1 distance 0.00
#   Prediction 2: Class 'panda' with L1 distance 2924.35
#   Prediction 3: Class 'panda' with L1 distance 3116.38
#   Prediction 4: Class 'panda' with L1 distance 3141.30
#   Prediction 5: Class 'dogs' with L1 distance 3217.74
#
# Test Image 9:
#   Prediction 1: Class 'dogs' with L1 distance 0.00
#   Prediction 2: Class 'dogs' with L1 distance 3902.28
#   Prediction 3: Class 'cats' with L1 distance 3913.22
#   Prediction 4: Class 'dogs' with L1 distance 3952.98
#   Prediction 5: Class 'dogs' with L1 distance 3996.66
#
# Test Image 10:
#   Prediction 1: Class 'panda' with L1 distance 0.00
#   Prediction 2: Class 'dogs' with L1 distance 3921.91
#   Prediction 3: Class 'cats' with L1 distance 3934.19
#   Prediction 4: Class 'panda' with L1 distance 4156.58
#   Prediction 5: Class 'dogs' with L1 distance 4166.29
#
#
# Top 5 Predictions for L2 Distance (10 test samples):
#
# Test Image 1:
#   Prediction 1: Class 'cats' with L2 distance 0.00
#   Prediction 2: Class 'dogs' with L2 distance 613.46
#   Prediction 3: Class 'dogs' with L2 distance 627.89
#   Prediction 4: Class 'dogs' with L2 distance 630.30
#   Prediction 5: Class 'dogs' with L2 distance 631.89
#
# Test Image 2:
#   Prediction 1: Class 'dogs' with L2 distance 0.00
#   Prediction 2: Class 'cats' with L2 distance 625.12
#   Prediction 3: Class 'cats' with L2 distance 628.21
#   Prediction 4: Class 'dogs' with L2 distance 634.77
#   Prediction 5: Class 'cats' with L2 distance 635.96
#
# Test Image 3:
#   Prediction 1: Class 'panda' with L2 distance 0.00
#   Prediction 2: Class 'dogs' with L2 distance 588.43
#   Prediction 3: Class 'dogs' with L2 distance 596.86
#   Prediction 4: Class 'cats' with L2 distance 614.79
#   Prediction 5: Class 'panda' with L2 distance 620.38
#
# Test Image 4:
#   Prediction 1: Class 'dogs' with L2 distance 0.00
#   Prediction 2: Class 'cats' with L2 distance 633.08
#   Prediction 3: Class 'cats' with L2 distance 633.14
#   Prediction 4: Class 'panda' with L2 distance 634.80
#   Prediction 5: Class 'dogs' with L2 distance 637.08
#
# Test Image 5:
#   Prediction 1: Class 'panda' with L2 distance 0.00
#   Prediction 2: Class 'cats' with L2 distance 631.21
#   Prediction 3: Class 'dogs' with L2 distance 633.34
#   Prediction 4: Class 'cats' with L2 distance 637.64
#   Prediction 5: Class 'panda' with L2 distance 637.82
#
# Test Image 6:
#   Prediction 1: Class 'panda' with L2 distance 0.00
#   Prediction 2: Class 'cats' with L2 distance 633.65
#   Prediction 3: Class 'cats' with L2 distance 634.51
#   Prediction 4: Class 'dogs' with L2 distance 634.91
#   Prediction 5: Class 'dogs' with L2 distance 636.33
#
# Test Image 7:
#   Prediction 1: Class 'panda' with L2 distance 0.00
#   Prediction 2: Class 'panda' with L2 distance 637.27
#   Prediction 3: Class 'panda' with L2 distance 639.73
#   Prediction 4: Class 'dogs' with L2 distance 640.71
#   Prediction 5: Class 'panda' with L2 distance 642.36
#
# Test Image 8:
#   Prediction 1: Class 'panda' with L2 distance 0.00
#   Prediction 2: Class 'cats' with L2 distance 599.21
#   Prediction 3: Class 'cats' with L2 distance 620.43
#   Prediction 4: Class 'cats' with L2 distance 621.62
#   Prediction 5: Class 'cats' with L2 distance 622.10
#
# Test Image 9:
#   Prediction 1: Class 'dogs' with L2 distance 0.00
#   Prediction 2: Class 'panda' with L2 distance 642.76
#   Prediction 3: Class 'dogs' with L2 distance 643.28
#   Prediction 4: Class 'dogs' with L2 distance 643.59
#   Prediction 5: Class 'dogs' with L2 distance 644.33
#
# Test Image 10:
#   Prediction 1: Class 'panda' with L2 distance 0.00
#   Prediction 2: Class 'panda' with L2 distance 641.71
#   Prediction 3: Class 'panda' with L2 distance 643.52
#   Prediction 4: Class 'panda' with L2 distance 643.84
#   Prediction 5: Class 'panda' with L2 distance 643.87

# %%
random.shuffle(train_data)
test_images = []
neighbours = 3
test_count = 30  # changed from 50 to 30

for i in range(test_count):
    test_image = train_data[i][0]
    test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
    test_images.append([test_image_gray, train_data[i][1]])

accurate = 0

for test_image_gray in test_images:
    distances2 = []
    pred = None
    for train_image, class_num in train_data:
        train_image_gray = cv2.cvtColor(train_image, cv2.COLOR_BGR2GRAY)
        dist2 = l2_dist(test_image_gray[0], train_image_gray)
        distances2.append((dist2, class_num))
    distances2.sort(key=lambda x: x[0])

    prediction_classes = [[cl[0], Categories[cl[1]]] for cl in distances2[:neighbours]]
    occurrences_dict = {pc[1]: [0, 0] for pc in prediction_classes}

    for pc in prediction_classes:
        occurrences_dict[pc[1]][0] += 1  # vote count
        occurrences_dict[pc[1]][1] += pc[0]  # total distance

    elements_at_index_0 = [value[0] for value in occurrences_dict.values()]
    max_count_0 = max(elements_at_index_0)
    keys_with_max_value = [key for key, value in occurrences_dict.items() if value[0] == max_count_0]

    if len(keys_with_max_value) == 1:
        pred = keys_with_max_value[0]
    else:
        elements_at_index_1 = [value[1] for value in occurrences_dict.values()]
        min_count_1 = min(elements_at_index_1)
        keys_with_min_value = [key for key, value in occurrences_dict.items() if value[1] == min_count_1]
        pred = keys_with_min_value[0]

    truth = Categories[test_image_gray[1]]

    plt.figure()
    plt.imshow(test_image_gray[0], cmap="gray")
    plt.xlabel(f"Truth: {truth}, Pred: {pred}")
    plt.show()

    if truth == pred:
        accurate += 1

print(f'Correctly predicted {accurate} images out of {test_count}, overall accuracy: {(accurate/test_count)*100:.2f} %')
# Out:
# Correctly predicted 26 images out of 30, overall accuracy: 86.67 %
